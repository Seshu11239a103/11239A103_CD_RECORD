# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hotel Booking

# %%
text = input("Enter Hotel Booking Details:\n")
print("Lines:", len(text.split("\n")))
print("Spaces:", text.count(" "))
# Out:
# Enter Hotel Booking Details:
# book is not available
# Lines: 1
# Spaces: 3

# %% [markdown]
# Exam Question Paper

# %%
text = input("Enter Exam Question Paper:\n")
print("Lines:", len(text.split("\n")))
print("Spaces:", text.count(" "))
# Out:
# Enter Exam Question Paper:
# question no one
# Lines: 1
# Spaces: 2
