# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Car VIN Validation

# %%
def check_identifier(s):
    if s[0].isalpha() and s.replace("_", "").isalnum():
        print("Valid VIN Identifier")
    else:
        print("Invalid VIN Identifier")

# Input
check_identifier(input("Enter Car VIN: "))
# Out:
# Enter Car VIN: car_123
# Valid VIN Identifier

# %% [markdown]
# b) Bakery Item Code

# %%
def check_identifier(s):
    if s[0].isalpha() and s.replace("_", "").isalnum():
        print("Valid Bakery Code")
    else:
        print("Invalid Bakery Code")

# Input
check_identifier(input("Enter Item Code: "))
# Out:
# Enter Item Code: 123car
# Invalid Bakery Code
