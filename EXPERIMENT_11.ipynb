# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) School Database

# %%
# Symbol table using dictionary
symbol_table = {}

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")
    roll = input("Enter roll number: ")
    symbol_table[name] = roll

print("Symbol Table:")
for key, value in symbol_table.items():
    print(key, ":", value)
# Out:
# Enter number of students: 2
# Enter student name: ravi
# Enter roll number: 103
# Enter student name: bhaskar
# Enter roll number: 101
# Symbol Table:
# ravi : 103
# bhaskar : 101

# %% [markdown]
# b) Bakery Inventory

# %%
symbol_table = {}

n = int(input("Enter number of items: "))

for i in range(n):
    item = input("Enter item name: ")

    try:
        price = int(input("Enter price: "))
        symbol_table[item] = price
    except:
        print("Invalid price! Enter number only.")
        break

print("Symbol Table:")
for key, value in symbol_table.items():
    print(key, ":", value)
# Out:
# Enter number of items: 2
# Enter item name: board
# Enter price: 43
# Enter item name: pen
# Enter price: 10
# Symbol Table:
# board : 43
# pen : 10
