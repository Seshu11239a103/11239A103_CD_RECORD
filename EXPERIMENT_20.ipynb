# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 4. Count blank spaces and number of lines

# %%
text = input("Enter text:\n")

lines = text.split("\n")
spaces = text.count(" ")

print("Lines:", len(lines))
print("Spaces:", spaces)
# Out:
# Enter text:
# hi this is Seshu Kumar Yallapragada
# Lines: 1
# Spaces: 5
