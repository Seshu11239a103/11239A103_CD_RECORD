# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Restaurant Billing Calculation

# %%
exp = "total = price * qty"

# Quadruple: (op, arg1, arg2, result)
quad = ("*", "price", "qty", "t1")

# Triple: (op, arg1, arg2)
triple = ("*", "price", "qty")

print("Quadruple:", quad)
print("Triple:", triple)
# Out:
# Quadruple: ('*', 'price', 'qty', 't1')
# Triple: ('*', 'price', 'qty')

# %% [markdown]
# b) Car Fuel Calculation

# %%
exp = "fuel = distance / mileage"

# Quadruple
quad = ("/", "distance", "mileage", "t1")

# Triple
triple = ("/", "distance", "mileage")

print("Quadruple:", quad)
print("Triple:", triple)
# Out:
# Quadruple: ('/', 'distance', 'mileage', 't1')
# Triple: ('/', 'distance', 'mileage')
