# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Banking Transaction Log Example

# %%
def is_balanced(expr):
    stack = []
    pairs = {')': '(', '}': '{', ']': '['}

    for char in expr:
        if char in "({[":
            stack.append(char)
        elif char in ")}]":
            if not stack or stack[-1] != pairs[char]:
                return False
            stack.pop()

    return len(stack) == 0


def banking_log_check():
    expr = input("Enter Banking Transaction Expression: ")

    if is_balanced(expr):
        print("Valid Banking Transaction Log (Parentheses Balanced)")
    else:
        print("Invalid Banking Transaction Log (Parentheses Not Balanced)")


# Run
banking_log_check()
# Out:
# Enter Banking Transaction Expression: Deposit(Amount[5000] + Charges{50})
# Valid Banking Transaction Log (Parentheses Balanced)

# %% [markdown]
# b) School Mark Sheet Formula

# %%
def marksheet_check():
    expr = input("Enter Mark Sheet Formula: ")

    if is_balanced(expr):
        print("Valid Mark Sheet Formula (Parentheses Balanced)")
    else:
        print("Invalid Mark Sheet Formula (Parentheses Not Balanced)")


# Run
marksheet_check()
# Out:
# Enter Mark Sheet Formula:  (Maths[90] + Science[85] + (English[88]))
# Valid Mark Sheet Formula (Parentheses Balanced)
