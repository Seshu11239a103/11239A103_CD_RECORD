# %% [markdown]
# <a href="https://colab.research.google.com/github/Seshu11239a103/11239A103_CD_RECORD/blob/main/EXPERIMENT_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Delivery Route Grammar

# %%
grammar = {"S": ["road", "path"]}

print("LEADING(S):", set(grammar["S"]))
print("TRAILING(S):", set(grammar["S"]))
# Out:
# LEADING(S): {'path', 'road'}
# TRAILING(S): {'path', 'road'}

# %% [markdown]
# b) Car Assembly Line Grammar

# %%
grammar = {"S": ["engine", "body"]}

print("LEADING(S):", set(grammar["S"]))
print("TRAILING(S):", set(grammar["S"]))
# Out:
# LEADING(S): {'body', 'engine'}
# TRAILING(S): {'body', 'engine'}
